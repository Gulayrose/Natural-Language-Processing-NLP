# %% [markdown]
# <a href="https://colab.research.google.com/github/Gulayrose/Natural-Language-Processing-NLP/blob/main/NLP_OCR_Screening_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screen Shot 2022-07-26 at 8.17.30 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-07-26 at 8.17.47 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-07-26 at 8.17.56 AM.png](data:image/png;base64,...)

# %%
import numpy as np
import nltk


class TFIDF:

    def term_frequency(self, term, sentence):
        pass

    def inverse_document_frequency(self, term, corpus):
        # please use nltk.word_tokenize
        pass

    def tfidf(self, term, sentence, corpus):
        pass

# %% [markdown]
# ![Screen Shot 2022-07-26 at 8.18.04 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-07-26 at 8.18.14 AM.png](data:image/png;base64,...)

# %%
path = '/content/drive/MyDrive/Colab Datas/medical_data.csv'

# %%
import pandas as pd
from scipy import stats


def perform_tests(data):
    return {
        'mann_whitney': None,
        'ttest': None,
        'chi_square': None,
        'shapiro_wilk': None
    }

# %% [markdown]
# ![Screen Shot 2022-07-26 at 8.18.23 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-07-26 at 8.27.06 AM.png](data:image/png;base64,...)

# %%
from gensim.corpora import Dictionary
from gensim.models import TfidfModel
from gensim.models import Word2Vec
import numpy as np

# You can access all models by uncommenting the following command
# models = {
#            "w2v": Word2Vec.load("models/w2v"),
#            "tfidf": TfidfModel.load("models/tfidf"),
#            "dct": Dictionary.load("models/dct"),
#        }

# You can use this helper function to get tfidf weights for given
# sentence and for accessed models
def get_tfidf_weights(models, sentence):
    transformed = models["dct"].doc2bow(sentence.split())
    tfidf_dct = {
        models["dct"][key]: value for (key, value) in models["tfidf"][transformed]
    }
    return tfidf_dct


def embed_sentence(models, sentence):

    return {"w2v_embedding": None, "tfidf_embedding": None}
